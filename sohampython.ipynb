# %%
import pandas as pd

# %%
# !pip install pandas
# Out:
# ...
#      |████████████████████████████████| 9.5 MB 5.1 MB/s eta 0:00:01     |▋                               | 194 kB 5.1 MB/s eta 0:00:02
# ...
#      |████████████████████████████████| 510 kB 28.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 14.5 MB 19.5 MB/s eta 0:00:01    |███████▍                        | 3.4 MB 19.5 MB/s eta 0:00:01
# ...

# %%
caschool = pd.read_stata("caschool.dta")

# %%
caschool
# Out:
#      observation_number  dist_cod       county  \
# 0                   1.0   75119.0      Alameda
# 1                   2.0   61499.0        Butte
# 2                   3.0   61549.0        Butte
# 3                   4.0   61457.0        Butte
# 4                   5.0   61523.0        Butte
# ..                  ...       ...          ...
# 415               416.0   68957.0    San Mateo
# 416               417.0   69518.0  Santa Clara
# 417               418.0   72611.0      Ventura
# 418               419.0   72744.0         Yuba
# 419               420.0   72751.0         Yuba
#
#                             district gr_span  enrl_tot    teachers   calw_pct  \
# 0                 Sunol Glen Unified   KK-08     195.0   10.900000   0.510200
# 1               Manzanita Elementary   KK-08     240.0   11.150000  15.416700
# 2        Thermalito Union Elementary   KK-08    1550.0   82.900002  55.032299
# 3    Golden Feather Union Elementary   KK-08     243.0   14.000000  36.475399
# ...
